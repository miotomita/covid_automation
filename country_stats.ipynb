# %%
import pandas as pd
import numpy as np
from datetime import datetime,timedelta

# %%
countries = pd.read_csv('https://raw.githubusercontent.com/kazuhirokida/classification/master/JHU_Classification.csv',na_filter=False)

# %%
jhu = pd.read_csv('https://github.com/kazuhirokida/covid-19/raw/master/countries.csv',na_filter=False)

# %%
iso = pd.read_csv('https://raw.githubusercontent.com/kazuhirokida/classification/master/ISO.csv',na_filter=False)

# %%
countries['Japanese'] = countries.ISO2.map(jhu.set_index('Code').Japanese.to_dict())
countries['latlong'] = countries.ISO2.map(jhu.set_index('Code').latlong.to_dict())
countries['Numeric'] = countries.ISO2.map(iso.set_index('Alpha-2 code').Numeric.to_dict())

# %%
countries = countries.append(pd.Series({'ISO2':'VU','ISO3':'VUT','Country':'Vanuatu','Region':'Oceania',
                      'Classification':'Developing','Japanese':'バヌアツ','latlong':'-17.734,168.323','Numeric':548}),ignore_index=True)

# %%
countries
# Out:
#     ISO2 ISO3                   Country   Region Classification   Japanese  \
# 0     DZ  DZA                   Algeria   Africa     Developing     アルジェリア
# 1     AO  AGO                    Angola   Africa     Developing       アンゴラ
# 2     BJ  BEN                     Benin   Africa     Developing        ベナン
# 3     BW  BWA                  Botswana   Africa     Developing       ボツワナ
# 4     BF  BFA              Burkina Faso   Africa     Developing    ブルキナファソ
# ..   ...  ...                       ...      ...            ...        ...
# 219   MP  MNP  Northern Mariana Islands  Oceania     Developing        NaN
# 220   PG  PNG          Papua New Guinea  Oceania     Developing  パプアニューギニア
# 221   MH  MHL          Marshall Islands  Oceania     Developing    マーシャル諸島
# 222   SB  SLB           Solomon Islands  Oceania     Developing     ソロモン諸島
# 223   VU  VUT                   Vanuatu  Oceania     Developing       バヌアツ
#
#              latlong  Numeric
# 0       28.723,2.868     12.0
# 1     -12.768,15.743     24.0
# 2        9.359,2.611    204.0
# 3     -21.980,23.662     72.0
# 4      12.524,-1.855    854.0
# ..               ...      ...
# 219              NaN    580.0
# 220   -5.690,143.400    598.0
# 221    7.106,171.194    584.0
# 222   -9.441,159.974     90.0
# 223  -17.734,168.323    548.0
#
# [224 rows x 8 columns]

# %%
un = pd.read_csv('https://population.un.org/wpp/Download/Files/1_Indicators%20(Standard)/CSV_FILES/WPP2019_TotalPopulationBySex.csv')
un = un[(un.Time==2020)&(un.Variant=='Medium')]

# %%
countries['Region_j'] = countries.Region.map(
    {'Africa':'アフリカ','Asia':'アジア','Cruise Liner':'クルーズ船','Europe':'欧州','Latin America and Caribbean':'南米','Middle East':'中東',
     'North America':'北米','Oceania':'オセアニア'})

# %%
countries[countries.Numeric.isna()]
# Out:
#     ISO2  ISO3           Country        Region Classification  \
# 82   DP*   DP*  Diamond Princess  Cruise Liner         Other*
# 83   MS*  MSZ*        MS Zaandam  Cruise Liner         Other*
# 93   CI*   CI*   Channel Islands        Europe      Developed
# 113   XK   XKX            Kosovo        Europe     Developing
#
#                 Japanese         latlong  Numeric Region_j
# 82   ダイヤモンド・プリンセス（クルーズ船）  34.000,143.000      NaN    クルーズ船
# 83        MSザーンダム（クルーズ船）                      NaN    クルーズ船
# 93                   NaN             NaN      NaN       欧州
# 113                  コソボ   42.662,21.158      NaN       欧州

# %%
who = pd.read_csv('https://covid19.who.int/WHO-COVID-19-global-data.csv',na_filter=False)
who.columns = who.columns.str.replace(' ','')

# %%
who_region = who[['Country_code','WHO_region']].drop_duplicates()

# %%
countries['Region_who'] = countries['ISO2'].map(who_region.set_index('Country_code').WHO_region.to_dict())

# %%
countries[countries.Region_who.isna()]
# Out:
#    ISO2  ISO3           Country        Region Classification  \
# 54   EH   ESH    Western Sahara        Africa     Developing
# 63   HK   HKG         Hong Kong          Asia     Developing
# 69   MO   MAC             Macau          Asia     Developing
# 78   TW   TWN           Taiwan*          Asia     Developing
# 82  DP*   DP*  Diamond Princess  Cruise Liner         Other*
# 83  MS*  MSZ*        MS Zaandam  Cruise Liner         Other*
# 93  CI*   CI*   Channel Islands        Europe      Developed
#
#                Japanese         latlong  Numeric Region_j Region_who
# 54                 西サハラ  24.860,-13.674    732.0     アフリカ        NaN
# 63                   香港  22.287,114.143    344.0      アジア        NaN
# 69                  マカオ  22.159,113.564    446.0      アジア        NaN
# 78                   台湾  24.014,121.111    158.0      アジア        NaN
# 82  ダイヤモンド・プリンセス（クルーズ船）  34.000,143.000      NaN    クルーズ船        NaN
# 83       MSザーンダム（クルーズ船）                      NaN    クルーズ船        NaN
# 93                  NaN             NaN      NaN       欧州        NaN

# %%
countries['population'] = countries.Numeric.map(un.set_index('LocID').PopTotal.to_dict())

# %%
countries = countries.append(pd.Series({'ISO2':'NaN','ISO3':'NaN','Country':'Cruise Liner','Region':'Cruise Liner',
                      'Classification':'Other*','Japanese':'クルーズ船などその他','latlong':'34.000,143.000','Region_j':'クルーズ船',
                     'Numeric':'NaN'}),ignore_index=True)

# %%
countries
# Out:
#     ISO2 ISO3           Country        Region Classification    Japanese  \
# 0     DZ  DZA           Algeria        Africa     Developing      アルジェリア
# 1     AO  AGO            Angola        Africa     Developing        アンゴラ
# 2     BJ  BEN             Benin        Africa     Developing         ベナン
# 3     BW  BWA          Botswana        Africa     Developing        ボツワナ
# 4     BF  BFA      Burkina Faso        Africa     Developing     ブルキナファソ
# ..   ...  ...               ...           ...            ...         ...
# 220   PG  PNG  Papua New Guinea       Oceania     Developing   パプアニューギニア
# 221   MH  MHL  Marshall Islands       Oceania     Developing     マーシャル諸島
# 222   SB  SLB   Solomon Islands       Oceania     Developing      ソロモン諸島
# 223   VU  VUT           Vanuatu       Oceania     Developing        バヌアツ
# 224  NaN  NaN      Cruise Liner  Cruise Liner         Other*  クルーズ船などその他
#
#              latlong Numeric Region_j Region_who  population
# 0       28.723,2.868      12     アフリカ       AFRO   43851.043
# 1     -12.768,15.743      24     アフリカ       AFRO   32866.268
# 2        9.359,2.611     204     アフリカ       AFRO   12123.198
# 3     -21.980,23.662      72     アフリカ       AFRO    2351.625
# 4      12.524,-1.855     854     アフリカ       AFRO   20903.278
# ..               ...     ...      ...        ...         ...
# 220   -5.690,143.400     598    オセアニア       WPRO    8947.027
# 221    7.106,171.194     584    オセアニア       WPRO      59.194
# 222   -9.441,159.974      90    オセアニア       WPRO     686.878
# 223  -17.734,168.323     548    オセアニア       WPRO     307.150
# 224   34.000,143.000     NaN    クルーズ船        NaN         NaN
#
# [225 rows x 11 columns]

# %%
eu = ['アイルランド','イタリア','エストニア','オーストリア','オランダ','キプロス','ギリシャ',
     'クロアチア','スウェーデン','スペイン','スロバキア','スロベニア','チェコ','デンマーク',
     'ドイツ','ハンガリー','フィンランド','フランス','ブルガリア','ベルギー','ポーランド',
     'ポルトガル','マルタ','ラトビア','リトアニア','ルーマニア','ルクセンブルク','英国']

# %%
l = []

for i in countries.Japanese:
    if i in eu:
        l.append('EU')
    else:
        l.append(np.nan)

# %%
countries['EU_dummy'] = l

# %%
countries
# Out:
#     ISO2 ISO3           Country        Region Classification    Japanese  \
# 0     DZ  DZA           Algeria        Africa     Developing      アルジェリア
# 1     AO  AGO            Angola        Africa     Developing        アンゴラ
# 2     BJ  BEN             Benin        Africa     Developing         ベナン
# 3     BW  BWA          Botswana        Africa     Developing        ボツワナ
# 4     BF  BFA      Burkina Faso        Africa     Developing     ブルキナファソ
# ..   ...  ...               ...           ...            ...         ...
# 220   PG  PNG  Papua New Guinea       Oceania     Developing   パプアニューギニア
# 221   MH  MHL  Marshall Islands       Oceania     Developing     マーシャル諸島
# 222   SB  SLB   Solomon Islands       Oceania     Developing      ソロモン諸島
# 223   VU  VUT           Vanuatu       Oceania     Developing        バヌアツ
# 224  NaN  NaN      Cruise Liner  Cruise Liner         Other*  クルーズ船などその他
#
#              latlong Numeric Region_j Region_who  population EU_dummy
# 0       28.723,2.868      12     アフリカ       AFRO   43851.043      NaN
# 1     -12.768,15.743      24     アフリカ       AFRO   32866.268      NaN
# 2        9.359,2.611     204     アフリカ       AFRO   12123.198      NaN
# 3     -21.980,23.662      72     アフリカ       AFRO    2351.625      NaN
# 4      12.524,-1.855     854     アフリカ       AFRO   20903.278      NaN
# ..               ...     ...      ...        ...         ...      ...
# 220   -5.690,143.400     598    オセアニア       WPRO    8947.027      NaN
# 221    7.106,171.194     584    オセアニア       WPRO      59.194      NaN
# 222   -9.441,159.974      90    オセアニア       WPRO     686.878      NaN
# 223  -17.734,168.323     548    オセアニア       WPRO     307.150      NaN
# 224   34.000,143.000     NaN    クルーズ船        NaN         NaN      NaN
#
# [225 rows x 12 columns]

# %%
countries.to_csv('country_stats.csv', encoding='utf_8_sig')
